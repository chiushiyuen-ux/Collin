# %%
import sqlite3
import pandas as pd
import os

# %%
filename=r"C:\Users\chius\OneDrive\codes\python codes\ml codes\example to regressions.csv"
eg_df=pd.read_csv(filename)

# %%
link=r"C:\Users\chius\OneDrive\codes\python codes\ml codes\blank query.db"
connection=sqlite3.connect(link)
cursor=connection.cursor()
cursor.execute("create TABLE test (id INTEGER,name TEXT)")
query="SELECT * FROM test WHERE 1=0"
cursor.execute(query)
print(cursor.fetchall())
connection.close()
# Out:
# []

# %%
conn=sqlite3.connect('students data.db')
cursor=conn.cursor()
cursor.execute("CREATE TABLE IF NOT EXISTS students (sid INTEGER, score REAL)")
data_to_insert=eg_df[["sid","score"]].values.tolist()
cursor.executemany("INSERT INTO students (sid, score) VALUES (?, ?)", data_to_insert)
conn.commit()
cursor.execute("SELECT * FROM students")
results=cursor.fetchall()
print(results)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       2 cursor=conn.cursor()
#       3 cursor.execute("CREATE TABLE IF NOT EXISTS students (sid INTEGER, score REAL)")
# ----> 4 data_to_insert=eg_df[["sid","score"]].values.tolist()
#       5 cursor.executemany("INSERT INTO students (sid, score) VALUES (?, ?)", data_to_insert)
#       6 conn.commit()
#
# File c:\Users\chius\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# ...
