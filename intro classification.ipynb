# %%
#svm with just one variable

# %%
import numpy as np
import pandas as pd
from copy import deepcopy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.svm import SVC

def median(data):
    data=deepcopy(data)
    N=len(data)
    if N//2:
        median=(data[N//2+1]+data[N//2])/2
    else:
        median=(data[(N+1)//2])
    return median

def M(data,k): #kth central moment
    # central moments has lots of use,
    # for example: (--> means related to)
    # k=0-->total
    # k=1-->mean, k=2-->variance
    # k=3-->skewness, k=4-->kurtosis
    data=deepcopy(data)
    Mk=0
    for i in data:
        Mk+=(i)**k
    return Mk

file_name=r"C:\Users\chius\OneDrive\codes\python codes\ml codes\Example to Classification.csv"
df = pd.read_csv(file_name)
df_init=df.head(200)[df['Country']=='UK']
#df_init=df
N=df_init.shape[0]

print(df_init)
# Out:
#             Sales Person Country               Product        Date  \
# 0         Jehu Rudeforth      UK       Mint Chip Choco  04/01/2022
# 4         Jehu Rudeforth      UK   Peanut Butter Cubes  24/02/2022
# 6             Oby Sorrel      UK       99% Dark & Pure  25/01/2022
# 10   Rafaelita Blaksland      UK    Smooth Sliky Salty  13/01/2022
# 19        Curtice Advani      UK         85% Dark Bars  08/06/2022
# 23          Husein Augar      UK         Drinking Coco  14/03/2022
# 31   Rafaelita Blaksland      UK       99% Dark & Pure  29/06/2022
# 33      Karlen McCaffrey      UK          Almond Choco  30/06/2022
# 36        Andria Kimpton      UK        50% Dark Bites  24/08/2022
# 71          Gigi Bohling      UK          Almond Choco  10/01/2022
# 74           Van Tuxwell      UK   Organic Choco Syrup  26/08/2022
# 78           Van Tuxwell      UK       99% Dark & Pure  31/01/2022
# 90   Dennison Crosswaite      UK               Eclairs  24/03/2022
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# Australia      615
# India          552
# USA            537
# UK             534
# Canada         525
# New Zealand    519
# Name: count, dtype: int64

# %%
# possible questions
# Can we guess which country a sale happened in based on the product and the volume shipped?
# Can we predict which type of chocolate was sold?
# We could create a new label (e.g., "High" vs "Low") based on the Amount or Boxes Shipped?

# %%
df_init['Amount'] = df_init['Amount'].str.replace('US$', '', regex=False) \
                                     .str.replace(',', '', regex=False) \
                                     .str.strip() \
                                     .astype(float)
df_init
# Out:
#             Sales Person Country               Product        Date   Amount  \
# 0         Jehu Rudeforth      UK       Mint Chip Choco  04/01/2022   5320.0
# 4         Jehu Rudeforth      UK   Peanut Butter Cubes  24/02/2022  13685.0
# 6             Oby Sorrel      UK       99% Dark & Pure  25/01/2022  13685.0
# 10   Rafaelita Blaksland      UK    Smooth Sliky Salty  13/01/2022   4704.0
# 19        Curtice Advani      UK         85% Dark Bars  08/06/2022   1085.0
# 23          Husein Augar      UK         Drinking Coco  14/03/2022   3003.0
# 31   Rafaelita Blaksland      UK       99% Dark & Pure  29/06/2022  12446.0
# 33      Karlen McCaffrey      UK          Almond Choco  30/06/2022   6839.0
# 36        Andria Kimpton      UK        50% Dark Bites  24/08/2022   2653.0
# 71          Gigi Bohling      UK          Almond Choco  10/01/2022   5642.0
# 74           Van Tuxwell      UK   Organic Choco Syrup  26/08/2022   2002.0
# ...

# %%
Season={'Date':{'1':4,'2':4,'3':1,'4':1,'5':1,'6':2,
        '7':2,'8':2,'9':3,'10':3,'11':3,'12':4}}

df_init['Date']=pd.to_datetime(df_init['Date'],dayfirst=True)
df_init['Date']=df_init['Date'].dt.month
df_init=df_init.replace(Season).infer_objects(copy=False)
df_init
# Out:
#             Sales Person Country               Product  Date   Amount  \
# 0         Jehu Rudeforth      UK       Mint Chip Choco     1   5320.0
# 4         Jehu Rudeforth      UK   Peanut Butter Cubes     2  13685.0
# 6             Oby Sorrel      UK       99% Dark & Pure     1  13685.0
# 10   Rafaelita Blaksland      UK    Smooth Sliky Salty     1   4704.0
# 19        Curtice Advani      UK         85% Dark Bars     6   1085.0
# 23          Husein Augar      UK         Drinking Coco     3   3003.0
# 31   Rafaelita Blaksland      UK       99% Dark & Pure     6  12446.0
# 33      Karlen McCaffrey      UK          Almond Choco     6   6839.0
# 36        Andria Kimpton      UK        50% Dark Bites     8   2653.0
# 71          Gigi Bohling      UK          Almond Choco     1   5642.0
# 74           Van Tuxwell      UK   Organic Choco Syrup     8   2002.0
# 78           Van Tuxwell      UK       99% Dark & Pure     1   4725.0
# ...
